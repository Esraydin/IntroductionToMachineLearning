# %% [markdown]
# ## Matplotlib;
# veri görselleştirmesinde kullandığımız temel python kütüphanesidir. 2 ve 3 boyutlu çizimler yapmamızı sağlar. Matplotlib genelde 2 boyutlu çizimlerde kullanılırken, 3 boyutlu çizimlerde başka kütüphanelerden yararlanılır.

# %%
import matplotlib.pyplot as plt #kütüphanenin import edilmesi.
import numpy as np

# %%
x = np.arange(0, 10 ,0.1) #0'dan 0.1 artarak 10'a kadar.
y = np.sin(x) #sinüs grafiği

plt.plot(x,y) #graph creation

#grafik özellikleri
plt.title("Sinüs Grafiği") 
plt.xlabel("x ekseni")
plt.ylabel("y ekseni")

#grafik gösterimi
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
size = np.random.randint(50,150,50)

plt.scatter(x, y, c=colors, s = size)
#grafik özellikleri
plt.title("Point Chart")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.show()

# %%
data = np.random.randn(1000)

plt.hist(data, bins = 30)
plt.title("Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()

# %%
x = ['A', 'B', 'C', 'D', 'E']
y = np.random.randint(1, 10, 5)

# Graph creation
plt.bar(x, y)

# Determine chart properties
plt.title("Column Chart")
plt.xlabel("Categories")
plt.ylabel("Values")

# Show graphics
plt.show()

# %%
sizes = [30, 25, 15, 10, 5, 5]
#grafik oluşturma
plt.pie(sizes)
plt.title("Pie Chart")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
x = np.arange(-5, 5, 0.25)
y = np.arange(-5, 5, 0.25)
x, y = np.meshgrid(x, y)
r = np.sqrt(x**2 + y**2)
z = np.sin(r)

# 3D graphics creation
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# plotting graphics
ax.plot_surface(x, y, z)

# Determine chart properties
ax.set_title("3D Graphics")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")

plt.show()
